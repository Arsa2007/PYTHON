# %% [markdown]
# <a href="https://colab.research.google.com/github/Arsa2007/PYTHON/blob/main/Phone_loc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install phonenumbers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 19.3 MB/s eta 0:00:00
# ...

# %%
import phonenumbers
from phonenumbers import geocoder
import time, random

# %%
def start(target):
  print(f"[+] Phonetracer v2.1 -OSINT")
  print(f"[*] Target: {target}")
  print(f"[*] Initiating trace")
  p = phonenumbers.parse(target,None)
  r = geocoder.description_for_number(p,"en")
  print(f"[+] Location {r}")
start("+91-87796-91725")
# Out:
# [+] Phonetracer v2.1 -OSINT
# [*] Target: +91-87796-91725
# [*] Initiating trace
# [+] LocationIndia
