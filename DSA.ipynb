# %%
#finding max and min elements
n=int(input())
list1=input().split()

for i in range(0,n):
   
    (list1[i])=int(list1[(i)])
        
maxf=list1[0]
minf=list1[0]

for i in range(n):
    if minf>list1[i]:
        minf=list1[i]
    if maxf<list1[i]:
        maxf=list1[i]
        
print(maxf) 
print(minf)
# Out:
#  4
#  2 3 1 5
# 5
# 1

# %%
## find mean, median, mode
n=int(input())

list1=input().split()
list2=[]
sum=0

for i in range(0,n):
    list1[i]=int(list1[(i)])

#sort the given list    
list1.sort()    
maxf=list1[(n-1)] 


#sum the elements in the list
for i in range(n):
    sum+=list1[i]

#print the mean    
print(sum/n)

#find the median
if n%2==0:
    temp=n//2
    print((list1[temp-1]+list1[(temp)])/2)
else :
        print(list1[(n//2)])
# Out:
#  4
#  1 2 8 3
# 3.5
# 2.5

# %%
#finding mode, frequency of elements
n=int(input())

list1=input().split()

for i in range(0,n):
    list1[i]=int(list1[(i)])

maxc=0
maxe=list1[0]
for i  in list1:
 current=0    
 for j in list1:
     if i==j:
         current+=1
 if current>maxc:
     maxc=current
     maxe=i
print(maxe)
print(maxc)
# Out:
#  4
#  1 2 5 3
# 1
# 1

# %%
#second way to find frequency
n=int(input())

list1=input().split()

for i in range(0,n):
    list1[i]=int(list1[(i)])

list1.sort()
currentc=1
maxcount=0
maxele=list1[0]
for i in range(n-1):
    if list1[i]==list1[i+1]:
        currentc+=1
    else:
        maxcount=currentc
        maxele=list1[i]
        currentc=1
#comparing because we don't have an elemnt after n-1        
if currentc>maxcount:
    maxcount=currentc
    maxele=list1[-1]
print(maxele,maxcount)
# Out:
#  4
#  1 1 1 3
# 1 3
