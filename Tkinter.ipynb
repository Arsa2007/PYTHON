# %%
from tkinter import *
root=Tk()
#creating a label
m1label=Label(root,text='HELLO').grid(row=0,column=2)
label2=Label(root,text='ABC').grid(row=1,column=2)
#shove it onto the screen
m1label.grid(row=0,column=2)
label2.grid(row=1,column=2)
root.mainloop()
