# %% [markdown]
# <a href="https://colab.research.google.com/github/Arsa2007/PYTHON/blob/main/PP2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
time_data={'snapchat':120,'instagram':90,'twitter':130,'Facebook':110}
social_media=list(time_data.keys())
time=list(time_data.values())
plt.bar(social_media,time,color='violet',width=0.4)
plt.xlabel('SOCIAL MEDIA')
plt.ylabel('TIME SPEND')
plt.title('TIME SPEND ON SOCIAL MEDIA')
plt.grid(axis='y')
