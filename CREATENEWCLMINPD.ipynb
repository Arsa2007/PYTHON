# %% [markdown]
# <a href="https://colab.research.google.com/github/Arsa2007/PYTHON/blob/main/CREATENEWCLMINPD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
list1=[['abc',14242] ,['bsd',24221],['gfd',85886]]
emloyees=pd.DataFrame(list1,columns=['name','salary'])
def createBonusColumn(employees: pd.DataFrame) -> pd.DataFrame:
    employees['bonus']=employees['salary']*2
    return employees
